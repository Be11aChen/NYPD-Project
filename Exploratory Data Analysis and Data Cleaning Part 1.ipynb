# %%
#Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from google.cloud import storage

#Authenticate User
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# Defined my Google Cloud Storage bucket, folder, and file name
bucket_name = 'my-project-bucket-bc'
folder_name = 'landing'
file_name = 'nypd_mv_collisions'

# Initialize a client
storage_client = storage.Client()

# Get the bucket and the blob
bucket = storage_client.get_bucket(bucket_name)
blob = bucket.blob(folder_name + '/' + file_name)  # Include folder path

# Download the file to a local directory
local_file_path = '/tmp/' + file_name #The file downloaded from Google Cloud Storage will be stored in the /tmp/ directory
blob.download_to_filename(local_file_path)

# Loaded the data into a DataFrame
df = pd.read_csv(local_file_path)

# Print the descriptive statistics
print(df.describe())
# Out:
#            latitude     longitude  number_of_cyclist_injured  \
# count  1.835137e+06  1.835137e+06               2.068363e+06
# mean   4.062767e+01 -7.375208e+01               2.674531e-02
# std    1.981060e+00  3.724516e+00               1.633425e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066782e+01 -7.397487e+01               0.000000e+00
# 50%    4.072084e+01 -7.392727e+01               0.000000e+00
# 75%    4.076960e+01 -7.386673e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.000000e+00
#
#        number_of_cyclist_killed  number_of_motorist_injured  \
# count              2.068363e+06                2.068363e+06
# mean               1.140999e-04                2.222531e-01
# std                1.072632e-02                6.604107e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# ...

# %%
# Display DF information/list of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2068363 entries, 0 to 2068362
# Data columns (total 28 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   borough                        object
#  1   contributing_factor_vehicle_1  object
#  2   contributing_factor_vehicle_2  object
#  3   contributing_factor_vehicle_3  object
#  4   contributing_factor_vehicle_4  object
#  5   contributing_factor_vehicle_5  object
#  6   cross_street_name              object
#  7   timestamp                      object
#  8   latitude                       float64
#  9   longitude                      float64
#  10  location                       object
#  11  number_of_cyclist_injured      int64
#  12  number_of_cyclist_killed       int64
#  13  number_of_motorist_injured     int64
#  14  number_of_motorist_killed      int64
#  15  number_of_pedestrians_injured  int64
#  16  number_of_pedestrians_killed   int64
# ...

# %%
# Number of missing (null or N/A) fields in the observations
missing_counts = df.isna().sum()
missing_counts
# Out:
# borough                           643524
# contributing_factor_vehicle_1       6749
# contributing_factor_vehicle_2     320029
# contributing_factor_vehicle_3    1920733
# contributing_factor_vehicle_4    2035063
# contributing_factor_vehicle_5    2059352
# cross_street_name                 780834
# timestamp                              0
# latitude                          233226
# longitude                         233226
# location                          233226
# number_of_cyclist_injured              0
# number_of_cyclist_killed               0
# number_of_motorist_injured             0
# number_of_motorist_killed              0
# number_of_pedestrians_injured          0
# number_of_pedestrians_killed           0
# number_of_persons_injured              0
# number_of_persons_killed               0
# off_street_name                  1722124
# on_street_name                    438612
# unique_key                             0
# vehicle_type_code1                 13553
# ...

# %%
# Distribution of Data for Borough
plt.figure(figsize=(8, 6))
df['borough'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Borough')
plt.xlabel('Borough')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for contributing_factor_vehicle_1
plt.figure(figsize=(8, 6))
df['contributing_factor_vehicle_1'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Contributing Factor Vehicle 1')
plt.xlabel('Contributing Factor Vehicle 1')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for contributing_factor_vehicle_2
plt.figure(figsize=(8, 6))
df['contributing_factor_vehicle_2'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Contributing Factor Vehicle 2')
plt.xlabel('Contributing Factor Vehicle 2')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for contributing_factor_vehicle_3
plt.figure(figsize=(8, 6))
df['contributing_factor_vehicle_3'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Contributing Factor Vehicle 3')
plt.xlabel('Contributing Factor Vehicle 3')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for contributing_factor_vehicle_4
plt.figure(figsize=(8, 6))
df['contributing_factor_vehicle_4'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Contributing Factor Vehicle 4')
plt.xlabel('Contributing Factor Vehicle 4')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for contributing_factor_vehicle_5
plt.figure(figsize=(8, 6))
df['contributing_factor_vehicle_5'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Contributing Factor Vehicle 5')
plt.xlabel('Contributing Factor Vehicle 5')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for number_of_cyclist_injured
plt.figure(figsize=(8, 6))
df['number_of_cyclist_injured'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Number of Cyclit Injured')
plt.xlabel('Number of Cyclit Injured')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for number_of_cyclist_killed
plt.figure(figsize=(8, 6))
df['number_of_cyclist_killed'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Number of Cyclit Killed')
plt.xlabel('Number of Cyclit Killed')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for number_of_motorist_injured
plt.figure(figsize=(8, 6))
df['number_of_motorist_injured'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Number of Motorist Injured')
plt.xlabel('Number of Motorist Injured')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for number_of_motorist_killed
plt.figure(figsize=(8, 6))
df['number_of_motorist_killed'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Number of Motorist Killed')
plt.xlabel('Number of Motorist Killed')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for number_of_pedestrians_injured
plt.figure(figsize=(8, 6))
df['number_of_pedestrians_injured'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Number of Pedestrians Injured')
plt.xlabel('Number of Pedestrians Injured')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for number_of_pedestrians_killed
plt.figure(figsize=(8, 6))
df['number_of_pedestrians_killed'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Number of Pedestrians Killed')
plt.xlabel('Number of Pedestrians Killed')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for number_of_persons_injured
plt.figure(figsize=(8, 6))
df['number_of_persons_injured'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Number of People Injured')
plt.xlabel('Number of People Injured')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distribution of Data for number_of_persons_killed
plt.figure(figsize=(8, 6))
df['number_of_persons_killed'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Number of Persons Killed')
plt.xlabel('Number of Persons Killed')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Display the Min/Max Date
df['timestamp'] = pd.to_datetime(df['timestamp'])

min_date = df['timestamp'].min().strftime('%Y-%m-%d')
max_date = df['timestamp'].max().strftime('%Y-%m-%d')

print("The min date is", min_date)
print("The max date is", max_date)
# Out:
# The min date is 2012-07-01
# The max date is 2024-02-23
